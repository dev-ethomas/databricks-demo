# %%
print("Hello World")
print("Hello new world")

# %%
# %sql
SELECT "Hello world from SQL code"

# %%
_sqldf.count()

# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3

# %%
# %run ./includes/setup

# %%
print(full_name)

# %%
# %fs ls '/'

# %%
# %fs ls '/databricks-datasets/'

# %%
dbutils.fs.ls("/")
